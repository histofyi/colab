# %% [markdown]
# <a href="https://colab.research.google.com/github/histofyi/colab/blob/main/MHC_Class_I_structure_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab

import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda install -c schrodinger pymol-bundle
# Out:
# done
# done
#
# # All requested packages already installed.

# %%
from pymol import cmd, util
from IPython.display import Image

cmd.delete('all')
cmd.load('https://www.histo.fyi/structures/downloads/1hhk_1_abd.cif', 'class_i_alpha')
cmd.load('https://www.histo.fyi/structures/downloads/1hhk_1_peptide.cif', 'peptide')
cmd.reset()
cmd.color('gray80','class_i_alpha')
cmd.hide('cartoon', 'peptide')
cmd.show('sticks', 'peptide')
util.cbay('peptide')
cmd.png('outputs/test.png')
Image(filename='outputs/test.png')
